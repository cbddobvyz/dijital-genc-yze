# %%
import numpy
from pandas import DataFrame
from matplotlib import pyplot as plotter

from transformations import normalize_dataset
from SHARED.data_generator import generate_skewed_data_right, generate_skewed_data_left, generate_extreme_skewed_data_right

# %%
feature_a = 'feature_a'
feature_b = 'feature_b'
feature_c = 'feature_c'

sqrt = "SQRT"
log = "LOG"
reverse = "1/N"

# %%
# Variables

plot_hist_color = 'cyan'
plot_hist_alpha = 0.63
plot_bar_count = 1000

size = 100000

# %%
df_data = DataFrame({feature_a: generate_skewed_data_left(size=size),
                     feature_b: generate_skewed_data_right(size=size),
                     feature_c: generate_extreme_skewed_data_right(size=size)})

df_data = normalize_dataset(df=df_data, 
                            all_pos=True)

# %%
df_data.head()
# Out:
#    feature_a  feature_b  feature_c
# 0   0.826065   0.602873   0.040895
# 1   0.783967   0.398894   0.018140
# 2   0.831613   0.500102   0.003168
# 3   0.823586   0.208971   0.022882
# 4   0.881474   0.292361   0.006140

# %%
# Plot Feature A

plotter.hist(df_data['feature_a'], 
             plot_bar_count, 
             density=True, 
             color=plot_hist_color, 
             alpha=plot_hist_alpha);

# %%
plotter.hist(df_data['feature_b'], 
             plot_bar_count, 
             density=True, 
             color=plot_hist_color, 
             alpha=plot_hist_alpha);

# %%
plotter.hist(df_data['feature_c'], 
             plot_bar_count, 
             density=True, 
             color=plot_hist_color, 
             alpha=plot_hist_alpha);

# %%
# Apply Transformations on all Features
#   * Sqrt Transformation
#   * Logarithmic Transformation
#   * 1/N Transformation

for column in df_data:
    df_data[column + "_" + sqrt] = numpy.sqrt(df_data[column])
    df_data[column + "_" + log] = numpy.log2(df_data[column])
    df_data[column + "_" + reverse] = numpy.power(df_data[column], -1.0)

# %%
# Show Plots
#   * Sqrt on Feature A 

plotter.hist(df_data[feature_a + "_" + sqrt], 
             plot_bar_count, 
             density=True, 
             color=plot_hist_color, 
             alpha=plot_hist_alpha);

# %%
# Show Plots
#   * Log on Feature A 

plotter.hist(df_data[feature_a + "_" + log], 
             plot_bar_count, 
             range=(-1.0, 0.0), 
             density=True, 
             color=plot_hist_color, 
             alpha=plot_hist_alpha);

# %%
# Show Plots
#   * Reverse on Feature A 

plotter.hist(df_data[feature_a + "_" + reverse], 
             plot_bar_count, 
             range=(1.0, 3.0), 
             density=True, 
             color=plot_hist_color, 
             alpha=plot_hist_alpha);

# %%
df_data.head(1000)
# Out:
#      feature_a  feature_b  feature_c  feature_a_SQRT  feature_a_LOG  \
# 0     0.826065   0.602873   0.040895        0.908881      -0.275673
# 1     0.783967   0.398894   0.018140        0.885419      -0.351135
# 2     0.831613   0.500102   0.003168        0.911928      -0.266016
# 3     0.823586   0.208971   0.022882        0.907516      -0.280010
# 4     0.881474   0.292361   0.006140        0.938868      -0.182011
# ..         ...        ...        ...             ...            ...
# 995   0.836189   0.207915   0.081514        0.914434      -0.258099
# 996   0.812432   0.306961   0.040525        0.901350      -0.299680
# 997   0.725575   0.444390   0.086933        0.851807      -0.462803
# 998   0.903529   0.241714   0.190850        0.950541      -0.146358
# 999   0.908176   0.289557   0.006313        0.952983      -0.138956
#
#      feature_a_1/N  feature_b_SQRT  feature_b_LOG  feature_b_1/N  \
# 0         1.210558        0.776449      -0.730075       1.658725
# 1         1.275563        0.631580      -1.325924       2.506934
# 2         1.202483        0.707179      -0.999705       1.999592
# 3         1.214203        0.457133      -2.258626       4.785355
# 4         1.134464        0.540705      -1.774175       3.420424
# ..             ...             ...            ...            ...
# 995       1.195902        0.455977      -2.265934       4.809658
# 996       1.230872        0.554040      -1.703874       3.257745
# 997       1.378217        0.666626      -1.170101       2.250274
# 998       1.106772        0.491644      -2.048629       4.137126
# 999       1.101108        0.538105      -1.788079       3.453548
#
#      feature_c_SQRT  feature_c_LOG  feature_c_1/N
# 0          0.202225      -4.611928      24.452801
# 1          0.134686      -5.784666      55.126186
# 2          0.056285      -8.302208     315.655806
# 3          0.151268      -5.449651      43.702717
# 4          0.078359      -7.347510     162.862422
# ..              ...            ...            ...
# 995        0.285507      -3.616805      12.267807
# 996        0.201308      -4.625047      24.676178
# 997        0.294845      -3.523947      11.503074
# 998        0.436864      -2.389489       5.239719
# 999        0.079453      -7.307499     158.407757
#
# [1000 rows x 12 columns]

# %%
# Show Plots
#   * Sqrt on Feature B 

plotter.hist(df_data[feature_b + "_" + sqrt], 
             plot_bar_count, 
             density=True, 
             color=plot_hist_color, 
             alpha=plot_hist_alpha);

# %%
# Show Plots
#   * Log on Feature B 

plotter.hist(df_data[feature_b + "_" + log], 
             plot_bar_count, 
             range= (-5.0, 0.0), 
             density=True, 
             color=plot_hist_color, 
             alpha=plot_hist_alpha);

# %%
# Show Plots
#   * Reverse on Feature B 

plotter.hist(df_data[feature_b + "_" + reverse], 
             plot_bar_count, 
             range=(0.0, 20.0), 
             density=True, 
             color=plot_hist_color, 
             alpha=plot_hist_alpha);

# %%
# Show Plots
#   * Sqrt on Feature C 

plotter.hist(df_data[feature_c + "_" + sqrt], 
             plot_bar_count, 
             density=True, 
             color=plot_hist_color, 
             alpha=plot_hist_alpha);

# %%
# Show Plots
#   * Log on Feature C 

plotter.hist(df_data[feature_c + "_" + log], 
             plot_bar_count, 
             density=True, 
             color=plot_hist_color, 
             alpha=plot_hist_alpha);

# %%
# Show Plots
#   * Reverse on Feature C 

plotter.hist(df_data[feature_c + "_" + reverse], 
             plot_bar_count, 
             range=(0.0, 1000.0), 
             density=True, 
             color=plot_hist_color, 
             alpha=plot_hist_alpha);
